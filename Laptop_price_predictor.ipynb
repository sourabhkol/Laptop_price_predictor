# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv')

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company            TypeName  Inches  \
# 0                0           0   Apple           Ultrabook    13.3
# 1                1           1   Apple           Ultrabook    13.3
# 2                2           2      HP            Notebook    15.6
# 3                3           3   Apple           Ultrabook    15.4
# 4                4           4   Apple           Ultrabook    13.3
# ...            ...         ...     ...                 ...     ...
# 1298          1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299          1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300          1300        1300  Lenovo            Notebook    14.0
# 1301          1301        1301      HP            Notebook    15.6
# 1302          1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Unnamed: 0','Unnamed: 0.1','Price'],inplace=True)

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Warranty          1303 non-null   object
#  11  w_Price           1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(8)
# memory usage: 112.1+ KB

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df['w_Price'])
# Out:
# /tmp/ipykernel_11457/3536035816.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['w_Price'])
# <Axes: xlabel='w_Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Company'],y=df['w_Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight Warranty       w_Price  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37        Y   60671.88072
# 1        Intel HD Graphics 6000  macOS    1.34        Y   40711.19472
# ...

# %%
df['Touchscreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Touchscreen'],y=df['w_Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='w_Price'>

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#      Company     TypeName  Inches             ScreenResolution  \
# 1045      HP     Notebook    15.6            Full HD 1920x1080
# 1289    Asus    Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 990       HP      Netbook    12.5            Full HD 1920x1080
# 1179      HP     Notebook    15.6                     1366x768
# 757       HP  Workstation    15.6            Full HD 1920x1080
#
#                               Cpu  Ram                  Memory  \
# 1045   Intel Core i5 6300U 2.4GHz    8  256GB SSD +  500GB HDD
# 1289     Intel Core M 6Y30 0.9GHz    8               512GB SSD
# 990      Intel Core M 6Y75 1.2GHz    8               512GB SSD
# 1179   Intel Core i3 6100U 2.3GHz    4               500GB HDD
# 757   Intel Core i7 6700HQ 2.6GHz    8               256GB SSD
#
#                         Gpu       OpSys  Weight Warranty     w_Price  \
# 1045  Intel HD Graphics 520  Windows 10    1.84        N  84049.4664
# ...

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 834   Lenovo  Notebook    14.0  IPS Panel Full HD 1920x1080
# 1175    Asus  Notebook    14.0            Full HD 1920x1080
# 138   Lenovo  Notebook    15.6            Full HD 1920x1080
# 340     Dell  Notebook    15.6                     1366x768
# 1002    Dell  Notebook    15.6                     1366x768
#
#                                        Cpu  Ram     Memory  \
# 834             Intel Core i5 7300U 2.6GHz    8  256GB SSD
# 1175            Intel Core i3 7100U 2.4GHz    4  256GB SSD
# 138             Intel Core i5 7200U 2.5GHz    4    1TB HDD
# 340   Intel Celeron Dual Core N3060 1.6GHz    4  500GB HDD
# 1002            Intel Core i3 7100U 2.4GHz    4  128GB SSD
#
#                         Gpu       OpSys  Weight Warranty    w_Price  \
# 834   Intel HD Graphics 620  Windows 10    1.32        Y  74725.200
# 1175  Intel HD Graphics 620  Windows 10    2.00        Y  34826.472
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight Warranty       w_Price  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37        Y   60671.88072
# 1        Intel HD Graphics 6000  macOS    1.34        Y   40711.19472
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Warranty          1303 non-null   object
#  11  w_Price           1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  IPS               1303 non-null   int64
#  14  X_res             1303 non-null   int64
#  15  Y_res             1303 non-null   int64
# ...

# %%
df.corr()['w_Price']
# Out:
# /tmp/ipykernel_11457/3226392252.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['w_Price']
# Inches         0.067445
# Ram            0.735895
# Weight         0.211500
# w_Price        1.000000
# Touchscreen    0.191995
# IPS            0.248468
# X_res          0.556691
# Y_res          0.552837
# Name: w_Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 728     Dell            Notebook    15.6                         1366x768
# 370     Asus  2 in 1 Convertible    15.6  Full HD / Touchscreen 1920x1080
# 173  Toshiba            Notebook    15.6                         1366x768
# 367   Lenovo              Gaming    15.6      IPS Panel Full HD 1920x1080
# 90      Asus              Gaming    15.6                Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 728   Intel Core i5 7200U 2.5GHz    8               1TB HDD
# 370   Intel Core i7 7500U 2.7GHz   12  512GB SSD +  2TB HDD
# 173   Intel Core i3 7100U 2.4GHz    4             500GB HDD
# 367  Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
# 90             AMD FX 9830P 3GHz    8               1TB HDD
#
#                          Gpu       OpSys  Weight Warranty     w_Price  \
# 728       AMD Radeon R7 M445       Linux    2.32        N  23557.2192
# ...

# %%
df.corr()['w_Price']
# Out:
# /tmp/ipykernel_11457/3226392252.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['w_Price']
# Inches         0.067445
# Ram            0.735895
# Weight         0.211500
# w_Price        1.000000
# Touchscreen    0.191995
# IPS            0.248468
# X_res          0.556691
# Y_res          0.552837
# ppi            0.473361
# Name: w_Price, dtype: float64

# %%
df.drop(columns = ['Inches','ScreenResolution','X_res','Y_res'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight Warranty       w_Price  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37        Y   60671.88072
# 1        Intel HD Graphics 6000  macOS    1.34        Y   40711.19472
# 2         Intel HD Graphics 620  No OS    1.86        N   22977.00000
# 3            AMD Radeon Pro 455  macOS    1.83        N  101396.50200
# 4  Intel Iris Plus Graphics 650  macOS    1.37        Y   81681.43680
#
#    Touchscreen  IPS         ppi
# 0            0    1  226.983005
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight Warranty       w_Price  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37        Y   60671.88072
# 1        Intel HD Graphics 6000  macOS    1.34        Y   40711.19472
# 2         Intel HD Graphics 620  No OS    1.86        N   22977.00000
# 3            AMD Radeon Pro 455  macOS    1.83        N  101396.50200
# 4  Intel Iris Plus Graphics 650  macOS    1.37        Y   81681.43680
#
#    Touchscreen  IPS         ppi       Cpu Name
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight Warranty       w_Price  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37        Y   60671.88072
# 1        Intel HD Graphics 6000  macOS    1.34        Y   40711.19472
# 2         Intel HD Graphics 620  No OS    1.86        N   22977.00000
# 3            AMD Radeon Pro 455  macOS    1.83        N  101396.50200
# 4  Intel Iris Plus Graphics 650  macOS    1.37        Y   81681.43680
#
#    Touchscreen  IPS         ppi       Cpu Name      Cpu brand
# ...

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# /tmp/ipykernel_11457/4023190604.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# /tmp/ipykernel_11457/4023190604.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight Warranty       w_Price  Touchscreen  IPS         ppi  \
# 0  macOS    1.37        Y   60671.88072            0    1  226.983005
# 1  macOS    1.34        Y   40711.19472            0    0  127.677940
# 2  No OS    1.86        N   22977.00000            0    0  141.211998
# 3  macOS    1.83        N  101396.50200            0    1  220.534624
# 4  macOS    1.37        Y   81681.43680            0    1  226.983005
#
#        Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df.corr()['w_Price']
# Out:
# /tmp/ipykernel_11457/3226392252.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['w_Price']
# Ram              0.735895
# Weight           0.211500
# w_Price          1.000000
# Touchscreen      0.191995
# IPS              0.248468
# ppi              0.473361
# HDD             -0.096208
# SSD              0.666866
# Hybrid           0.005508
# Flash_Storage   -0.041813
# Name: w_Price, dtype: float64

# %%
df.drop(columns=['Memory','Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#   Warranty       w_Price  Touchscreen  IPS         ppi      Cpu brand  HDD  \
# 0        Y   60671.88072            0    1  226.983005  Intel Core i5    0
# 1        Y   40711.19472            0    0  127.677940  Intel Core i5    0
# 2        N   22977.00000            0    0  141.211998  Intel Core i5    0
# 3        N  101396.50200            0    1  220.534624  Intel Core i7    0
# 4        Y   81681.43680            0    1  226.983005  Intel Core i5    0
#
#    SSD
# 0  128
# 1    0
# 2  256
# 3  512
# 4  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#   Warranty       w_Price  Touchscreen  IPS         ppi      Cpu brand  HDD  \
# 0        Y   60671.88072            0    1  226.983005  Intel Core i5    0
# 1        Y   40711.19472            0    0  127.677940  Intel Core i5    0
# 2        N   22977.00000            0    0  141.211998  Intel Core i5    0
# 3        N  101396.50200            0    1  220.534624  Intel Core i7    0
# 4        Y   81681.43680            0    1  226.983005  Intel Core i5    0
#
#    SSD Gpu brand
# 0  128     Intel
# 1    0     Intel
# 2  256     Intel
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
df.drop(columns = ['Gpu'],inplace = True)
# Out:
# /tmp/ipykernel_11457/2778710281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['Gpu'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight Warranty       w_Price  Touchscreen  \
# 0   Apple  Ultrabook    8  macOS    1.37        Y   60671.88072            0
# 1   Apple  Ultrabook    8  macOS    1.34        Y   40711.19472            0
# 2      HP   Notebook    8  No OS    1.86        N   22977.00000            0
# 3   Apple  Ultrabook   16  macOS    1.83        N  101396.50200            0
# 4   Apple  Ultrabook    8  macOS    1.37        Y   81681.43680            0
#
#    IPS         ppi      Cpu brand  HDD  SSD Gpu brand
# 0    1  226.983005  Intel Core i5    0  128     Intel
# 1    0  127.677940  Intel Core i5    0    0     Intel
# 2    0  141.211998  Intel Core i5    0  256     Intel
# 3    1  220.534624  Intel Core i7    0  512       AMD
# 4    1  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['w_Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
# Out:
# /tmp/ipykernel_11457/3648919379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight Warranty       w_Price  Touchscreen  \
# 0   Apple  Ultrabook    8  macOS    1.37        Y   60671.88072            0
# 1   Apple  Ultrabook    8  macOS    1.34        Y   40711.19472            0
# 2      HP   Notebook    8  No OS    1.86        N   22977.00000            0
# 3   Apple  Ultrabook   16  macOS    1.83        N  101396.50200            0
# 4   Apple  Ultrabook    8  macOS    1.37        Y   81681.43680            0
#
#    IPS         ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0    1  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1    0  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2    0  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3    1  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4    1  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df['os'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['os'],y=df['w_Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['OpSys'],inplace = True)
# Out:
# /tmp/ipykernel_11457/3572285672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace = True)

# %%
df['Warranty'] = df['Warranty'].apply(lambda x:1 if x=='Y' else 0)
# Out:
# /tmp/ipykernel_11457/3357596309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Warranty'] = df['Warranty'].apply(lambda x:1 if x=='Y' else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight  Warranty       w_Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8    1.37         1   60671.88072            0    1
# 1   Apple  Ultrabook    8    1.34         1   40711.19472            0    0
# 2      HP   Notebook    8    1.86         0   22977.00000            0    0
# 3   Apple  Ultrabook   16    1.83         0  101396.50200            0    1
# 4   Apple  Ultrabook    8    1.37         1   81681.43680            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df['Warranty'].value_counts()
# Out:
# 0    689
# 1    613
# Name: Warranty, dtype: int64

# %%
df.corr()['w_Price']
# Out:
# /tmp/ipykernel_11457/3226392252.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['w_Price']
# Ram            0.735776
# Weight         0.210953
# Warranty       0.105281
# w_Price        1.000000
# Touchscreen    0.193783
# IPS            0.249643
# ppi            0.475331
# HDD           -0.096691
# SSD            0.666705
# Name: w_Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# /tmp/ipykernel_11457/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.distplot(df['w_Price'])
# Out:
# /tmp/ipykernel_11457/3536035816.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['w_Price'])
# <Axes: xlabel='w_Price', ylabel='Density'>

# %% [markdown]
# ## Removing Skewness from target column

# %%
sns.distplot(np.log(df['w_Price']))
# Out:
# /tmp/ipykernel_11457/2484237255.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['w_Price']))
# <Axes: xlabel='w_Price', ylabel='Density'>

# %%
X = df.drop(columns = ['w_Price'])
y = np.log(df['w_Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Warranty  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37         1            0    1
# 1      Apple           Ultrabook    8    1.34         1            0    0
# 2         HP            Notebook    8    1.86         0            0    0
# 3      Apple           Ultrabook   16    1.83         0            0    1
# 4      Apple           Ultrabook    8    1.37         1            0    1
# ...      ...                 ...  ...     ...       ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80         1            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30         1            1    1
# 1300  Lenovo            Notebook    2    1.50         1            0    0
# 1301      HP            Notebook    6    2.19         1            0    0
# 1302    Asus            Notebook    4    2.20         1            0    0
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# ...

# %%
y
# Out:
# 0       11.013236
# 1       10.614258
# 2       10.042249
# 3       11.526794
# 4       11.310582
#           ...
# 1298    10.271380
# 1299    11.125596
# 1300     9.246764
# 1301    10.451610
# 1302     9.723839
# Name: w_Price, Length: 1302, dtype: float64

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Warranty  Touchscreen  IPS  \
# 183   Toshiba            Notebook    8    2.00         0            0    0
# 1141      MSI              Gaming    8    2.40         0            0    0
# 1049     Asus             Netbook    4    1.20         0            0    0
# 1020     Dell  2 in 1 Convertible    4    2.08         1            1    1
# 878      Dell            Notebook    4    2.18         0            0    0
# ...       ...                 ...  ...     ...       ...          ...  ...
# 466      Acer            Notebook    4    2.20         0            0    0
# 299      Asus           Ultrabook   16    1.63         0            0    0
# 493      Acer            Notebook    8    2.20         0            0    0
# 527    Lenovo            Notebook    8    2.20         0            0    0
# 1193    Apple           Ultrabook    8    0.92         0            0    1
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# ...

# %%
X_test
# Out:
#      Company            TypeName  Ram  Weight  Warranty  Touchscreen  IPS  \
# 248       HP            Notebook    4    1.49         1            0    1
# 555     Asus            Notebook    4    2.00         0            0    0
# 1251      HP            Notebook    4    1.86         0            0    0
# 547   Lenovo            Notebook    4    2.15         0            0    0
# 885       HP  2 in 1 Convertible    4    1.28         0            1    0
# ...      ...                 ...  ...     ...       ...          ...  ...
# 1129      HP              Gaming    8    3.35         0            0    1
# 172   Lenovo            Notebook    4    2.20         1            0    0
# 322     Asus            Notebook    8    2.00         1            0    0
# 996       HP           Ultrabook    8    1.11         1            1    1
# 470       HP  2 in 1 Convertible    8    1.29         0            1    1
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# ...

# %%
y_train
# Out:
# 183     10.363702
# 1141    10.729116
# 1049     9.350492
# 1020    10.492629
# 878     10.504067
#           ...
# 466      9.838482
# 299     10.979535
# 493     10.049181
# 527      9.816929
# 1193    10.746637
# Name: w_Price, Length: 1106, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
X_train.head(1)
# Out:
#      Company  TypeName  Ram  Weight  Warranty  Touchscreen  IPS        ppi  \
# 183  Toshiba  Notebook    8     2.0         0            0    0  100.45467
#
#          Cpu brand  HDD  SSD Gpu brand       os
# 183  Intel Core i5    0  128     Intel  Windows

# %% [markdown]
# ## Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8099383159720102
# MAE 0.2101795473177455
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = Ridge(alpha = 10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8152415032203648
# MAE 0.20932528805804357
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Lasso

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = Lasso(alpha = 0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8097965785089039
# MAE 0.21117034224371584
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7939813006023769
# MAE 0.207681413801902
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7908093498234665
# MAE 0.21358513124001183
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7937550912840603
# MAE 0.20469042071109322

# %% [markdown]
# ## Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8775432932727696
# MAE 0.16752405511105334

# %% [markdown]
# ## Extratrees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[215], line 16
#       5 step2 = ExtraTreesRegressor(n_estimators=100,
#       6                               random_state=3,
#       7                               max_samples=0.5,
#       8                               max_features=0.75,
#       9                               max_depth=15)
#      11 pipe = Pipeline([
#      12     ('step1',step1),
#      13     ('step2',step2)
#      14 ])
# ---> 16 pipe.fit(X_train,y_train)
#      18 y_pred = pipe.predict(X_test)
#      20 print('R2 score',r2_score(y_test,y_pred))
#
# ...

# %% [markdown]
# ## AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7866411777090462
# MAE 0.2356575539941574
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8808754143063282
# MAE 0.16302882574157157

# %% [markdown]
# ## XgBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8819187079552261
# MAE 0.16216281779795522
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb)],weights=[5,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8828254415209138
# MAE 0.16472199056130393

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown = 'ignore'),[0,1,8,11,12])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /home/skol/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8778473080437582
# MAE 0.17110504621676081

# %% [markdown]
# ## Exporting the Model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight  Warranty       w_Price  \
# 0      Apple           Ultrabook    8    1.37         1   60671.88072
# 1      Apple           Ultrabook    8    1.34         1   40711.19472
# 2         HP            Notebook    8    1.86         0   22977.00000
# 3      Apple           Ultrabook   16    1.83         0  101396.50200
# 4      Apple           Ultrabook    8    1.37         1   81681.43680
# ...      ...                 ...  ...     ...       ...           ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80         1   28893.74400
# 1299  Lenovo  2 in 1 Convertible   16    1.30         1   67886.71200
# 1300  Lenovo            Notebook    2    1.50         1   10370.95200
# 1301      HP            Notebook    6    2.19         1   34600.03200
# 1302    Asus            Notebook    4    2.20         1   16711.27200
#
#       Touchscreen  IPS         ppi              Cpu brand   HDD  SSD  \
# ...

# %%
df['HDD'].value_counts()
# Out:
# 0       726
# 1000    408
# 500     134
# 2000     32
# 32        1
# 128       1
# Name: HDD, dtype: int64

# %%
X_train.head(1)
# Out:
#      Company  TypeName  Ram  Weight  Warranty  Touchscreen  IPS        ppi  \
# 183  Toshiba  Notebook    8     2.0         0            0    0  100.45467
#
#          Cpu brand  HDD  SSD Gpu brand       os
# 183  Intel Core i5    0  128     Intel  Windows

# %%
X_test.head(1)
# Out:
#     Company  TypeName  Ram  Weight  Warranty  Touchscreen  IPS         ppi  \
# 248      HP  Notebook    4    1.49         1            0    1  165.632118
#
#          Cpu brand  HDD  SSD Gpu brand       os
# 248  Intel Core i5  500    0     Intel  Windows
